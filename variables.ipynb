# %% [markdown]
# <a href="https://colab.research.google.com/github/raimandvi/python-basics/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Siri"
age = 25
height = 5.5

print("Name", name)
print("Age", age)
print("Height", height)
# Out:
# Name Siri
# Age 25
# Height 5.5
